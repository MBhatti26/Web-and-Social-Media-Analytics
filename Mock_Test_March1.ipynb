# %% [markdown]
# <a href="https://colab.research.google.com/github/MBhatti26/Web-and-Social-Media-Analytics/blob/main/Mock_Test_March1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from itertools import permutations    #to generate all permutations
import matplotlib.pyplot as plt      #for visualizing the result

# %%
from google.colab import files

uploaded=files.upload()
# Out:
#      <input type="file" id="files-85d9d5d7-f60e-4466-a1ce-208b8985d2c7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85d9d5d7-f60e-4466-a1ce-208b8985d2c7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Load dataset into pandas dataframe

df=pd.read_excel('Task 3 Shapley Values dataset.xlsx', index_col=None)

print(df)
# Out:
#    User  Partner Advertisement  Email   Sponsored Search   Order Value
# 0     1                    1.0     2.0                3.0         8751
# 1     2                    NaN     1.0                2.0         2812
# 2     3                    NaN     NaN                1.0         7182
# 3     4                    1.0     2.0                NaN         6172
# 4     5                    NaN     1.0                2.0         8912
# 5     6                    NaN     NaN                1.0         5627
# 6     7                    2.0     1.0                NaN         2382

# %%
#Replace NaN with 0

df=df.fillna(0)

print(df)
# Out:
#    User  Partner Advertisement  Email   Sponsored Search   Order Value
# 0     1                    1.0     2.0                3.0         8751
# 1     2                    0.0     1.0                2.0         2812
# 2     3                    0.0     0.0                1.0         7182
# 3     4                    1.0     2.0                0.0         6172
# 4     5                    0.0     1.0                2.0         8912
# 5     6                    0.0     0.0                1.0         5627
# 6     7                    2.0     1.0                0.0         2382

# %%
X = df[["Partner Advertisement", "Email ", "Sponsored Search "]] #Independant Variables
Y = df["Order Value"] #Dependant Variable

# %%
print(df.columns.tolist())  # Show column names
# Out:
# ['User', 'Partner Advertisement', 'Email ', 'Sponsored Search ', 'Order Value']

# %%
from sklearn.linear_model import LinearRegression

#train the model
model = LinearRegression().fit(X,Y)

print("Model trained successfully!")
# Out:
# Model trained successfully!

# %%
# prompt: import shap library and run shapley model

# !pip install shap

import shap

# Assuming X and model are defined as in the previous code
explainer = shap.Explainer(model, X)
shap_values = explainer(X)

# Visualize the first prediction's explanation
shap.plots.waterfall(shap_values[1])

# Summarize the effects of all the features
shap.summary_plot(shap_values, X)

# %%
 #prompt: import shap library and run shapley model

# !pip install shap

import shap

#X and model are defined above
explainer = shap.Explainer(model, X)
shap_values = explainer(X)

# Visualize the first prediction's explanation
shap.plots.waterfall(shap_values[0])

# Summarize the effects of all the features
shap.summary_plot(shap_values, X)

# %%
from IPython.display import display
display(ppc_results)

# %%
# Re-import required libraries after execution reset
import pandas as pd

# Given data from the scenario
total_searches = 189102  # Total users who searched
click_through_rate = 0.18  # 18% clicked on a deal
total_clicks = total_searches * click_through_rate  # Users who clicked on a deal
total_bookings = 756  # Users who completed a purchase

# Recreate the dataset (since execution state was reset)
df = pd.DataFrame({
    "User": [1, 2, 3, 4, 5, 6, 7],
    "Partner Advertisement": [1, 0, 0, 1, 0, 0, 2],
    "Email ": [2, 1, 1, 2, 1, 1, 1],
    "Sponsored Search ": [3, 2, 1, 0, 2, 1, 0],
    "Order Value": [8751, 2812, 7182, 6172, 8912, 5627, 2382]
})

# Compute conversion rate from click to order
conversion_rate_click_to_order = total_bookings / total_clicks  # % of users who booked after clicking

# Compute Average Order Value (AOV)
average_order_value = df["Order Value"].mean()

# Compute Expected Revenue Per Click (ERPC)
expected_revenue_per_click = average_order_value * conversion_rate_click_to_order

# Compute Optimal PPC Bid Price
optimal_ppc_bid = expected_revenue_per_click  # The website should bid no more than this

# Display results
ppc_results = pd.DataFrame({
    "Metric": [
        "Total Users Who Clicked on a Deal",
        "Conversion Rate (Click to Order)",
        "Average Order Value (AOV)",
        "Expected Revenue Per Click (ERPC)",
        "Optimal PPC Bid Price"
    ],
    "Value": [
        total_clicks,
        round(conversion_rate_click_to_order, 4),
        round(average_order_value, 2),
        round(expected_revenue_per_click, 2),
        round(optimal_ppc_bid, 2)
    ]
})
from IPython.display import display
display(ppc_results)
# Out:
#                               Metric       Value
# 0  Total Users Who Clicked on a Deal  34038.3600
# 1   Conversion Rate (Click to Order)      0.0222
# 2          Average Order Value (AOV)   5976.8600
# 3  Expected Revenue Per Click (ERPC)    132.7500
# 4              Optimal PPC Bid Price    132.7500

# %%
# prompt: calculate optimal ppc bid price using datset provided

import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import shap

# Given data from the scenario
total_searches = 189102  # Total users who searched
click_through_rate = 0.18  # 18% clicked on a deal
total_clicks = total_searches * click_through_rate  # Users who clicked on a deal
total_bookings = 756  # Users who completed a purchase

# Recreate the dataset (since execution state was reset)
df = pd.DataFrame({
    "User": [1, 2, 3, 4, 5, 6, 7],
    "Partner Advertisement": [1, 0, 0, 1, 0, 0, 2],
    "Email ": [2, 1, 1, 2, 1, 1, 1],
    "Sponsored Search ": [3, 2, 1, 0, 2, 1, 0],
    "Order Value": [8751, 2812, 7182, 6172, 8912, 5627, 2382]
})

# Compute conversion rate from click to order
conversion_rate_click_to_order = total_bookings / total_clicks  # % of users who booked after clicking

# Compute Average Order Value (AOV)
average_order_value = df["Order Value"].mean()

# Compute Expected Revenue Per Click (ERPC)
expected_revenue_per_click = average_order_value * conversion_rate_click_to_order

# Compute Optimal PPC Bid Price
optimal_ppc_bid = expected_revenue_per_click  # The website should bid no more than this

# Display results
ppc_results = pd.DataFrame({
    "Metric": [
        "Total Users Who Clicked on a Deal",
        "Conversion Rate (Click to Order)",
        "Average Order Value (AOV)",
        "Expected Revenue Per Click (ERPC)",
        "Optimal PPC Bid Price"
    ],
    "Value": [
        total_clicks,
        round(conversion_rate_click_to_order, 4),
        round(average_order_value, 2),
        round(expected_revenue_per_click, 2),
        round(optimal_ppc_bid, 2)
    ]
})
display(ppc_results)
# Out:
#                               Metric       Value
# 0  Total Users Who Clicked on a Deal  34038.3600
# 1   Conversion Rate (Click to Order)      0.0222
# 2          Average Order Value (AOV)   5976.8600
# 3  Expected Revenue Per Click (ERPC)    132.7500
# 4              Optimal PPC Bid Price    132.7500

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-e364aa75-072f-424c-96ba-91bc89867cbc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e364aa75-072f-424c-96ba-91bc89867cbc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("Layout.csv")
print(df)
# Out:
#          Unnamed: 0  Deal Selected  Deal Not Selected
# 0       All Layouts             54                146
# 1  Exisiting Layout             33                 67
# 2       Redesign V2             21                 79

# %%
# prompt: from above dataset run chi square test of independace. Independant variables are 'existing layout' and 'redesign V2' - in rows. We want to see if it impacts deals selected and deals not selected in columns. We want to test at 5% significance level.

import pandas as pd
from scipy.stats import chi2_contingency

# Assuming your DataFrame is named 'df'
# Create a contingency table
data = pd.DataFrame({
    "Deal Selected": [33, 21],  # Existing Layout vs. Redesign V2
    "Deal Not Selected": [67, 79]
}, index=["Existing Layout", "Redesign V2"])

# Perform the Chi-Square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Print the results
print("Chi-Square Statistic:", chi2)
print("P-value:", p)
print("Degrees of Freedom:", dof)
print("Expected Frequencies:\n", expected)

# Interpret the results at 5% significance level
alpha = 0.05
print("\nInterpretation:")
if p < alpha:
  print("Reject the null hypothesis. There is a significant association between 'existing layout' and 'redesign V2' on 'deals'.")
else:
  print("Fail to reject the null hypothesis. There is no significant association between 'existing layout' and 'redesign V2' on 'deals'.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-676705ef589e> in <cell line: 0>()
#      12
#      13 # Perform the Chi-Square test
# ---> 14 chi2, p, dof, expected = chi2_contingency(contingency_table)
#      15
#      16 # Print the results
#
# NameError: name 'contingency_table' is not defined

# %%
print(df.columns)  # Check the actual column names

df = df.drop(columns=['Unnamed: 0'])  # Drop the 'Unnamed: 0' column
# Out:
# Index(['Unnamed: 0', 'Deal Selected', 'Deal Not Selected'], dtype='object')

# %%
# prompt: from above dataset run chi square test of independace. Independant variables are 'existing layout' and 'redesign V2' - in rows. We want to see if it impacts deals selected and deals not selected in columns. We want to test at 5% significance level.

import pandas as pd
from scipy.stats import chi2_contingency

# Assuming your DataFrame is named 'df'

# Create a contingency table
data = pd.DataFrame({
    "Deal Selected": [33, 21],  # Existing Layout vs. Redesign V2
    "Deal Not Selected": [67, 79]}, index=["Existing Layout", "Redesign V2"])

# %%
# prompt: from above dataset run chi square test of independace. Independant variables are 'existing layout' and 'redesign V2' - in rows. We want to see if it impacts deals selected and deals not selected in columns. We want to test at 5% significance level.

import pandas as pd
from scipy.stats import chi2_contingency

# Assuming your DataFrame is named 'df'

# Create a contingency table
data = pd.DataFrame({
    "Deal Selected": [33, 21],  # Existing Layout vs. Redesign V2
    "Deal Not Selected": [67, 79]}, index=["Existing Layout", "Redesign V2"])

# Perform the Chi-Square test
# The 'data' DataFrame is used here as the contingency table
chi2, p, dof, expected = chi2_contingency(data)

# Print the results
print("Chi-Square Statistic:", chi2)
print("P-value:", p)
print("Degrees of Freedom:", dof)
print("Expected Frequencies:\n", expected)

# Interpret the results at 5% significance level
alpha = 0.05
print("\nInterpretation:")
if p < alpha:
  print("Reject the null hypothesis. There is a significant association between 'existing layout' and 'redesign V2' on 'deals'.")
else:
  print("Fail to reject the null hypothesis. There is no significant association between 'existing layout' and 'redesign V2' on 'deals'.")
# Out:
# Chi-Square Statistic: 3.069507864028412
# P-value: 0.07977361830024723
# Degrees of Freedom: 1
# Expected Frequencies:
#  [[27. 73.]
#  [27. 73.]]
#
# Interpretation:
# Fail to reject the null hypothesis. There is no significant association between 'existing layout' and 'redesign V2' on 'deals'.

# %%
data =pd.DataFrame({
    "Deal Selected": [33,27],
    "Deal Not Selected": [67,79]
}, index=["Existing Layout", "Redesign V2"])
